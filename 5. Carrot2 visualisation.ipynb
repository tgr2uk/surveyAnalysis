# %% [markdown]
# # Clustering of keywords using Carrot2

# %% [markdown]
# ## Analyses
# 1. ~~Simple keyword analysis~~
#     * ~~tag cloud / bar chart visualisation~~
# 2. ~~Keyword analysis using word embeddings to conflate synonyms~~
#     * Visualization of 2.?
# 3. ~~Sentiment analysis, e.g. pos/neg/neutral etc.~~
# 4. ~~Compare different cohorts, e.g. based on career stage, geography etc.  (if we have this data).~~
#    * ~~Need to prioritise stratifications~~
# 5. Clustering of keywords, possibly using Carrot2 or similar

# %% [markdown]
# Process:
# * aggregate data into paired columns
# * extract and upload to Carrot2, https://search.carrot2.org/#/workbench
# * experiment with different algos & config settings
#     * k-means with k=12 produces useful cluters & labels

# %% [markdown]
# ## Q1: What are the TWO major challenges faced by embryologists in the workplace?

# %% [markdown]
# ![file-treemap.jpg](attachment:5e8ece4b-3683-4b11-ad75-86cbbcc5ef77.jpg)

# %% [markdown]
# ## Q2: What are the TWO major challenges faced by the embryology profession, in general?

# %% [markdown]
# ![file-treemap (2).jpg](attachment:66447a4c-2249-4fc6-ba28-176f3f3f6642.jpg)

# %% [markdown]
# ## Q3: Provide TWO suggestions to improve embryologists' working conditions

# %% [markdown]
# ![file-treemap (3).jpg](attachment:e2e60079-4d9e-4be1-bf5d-5147afb02f9e.jpg)

# %% [markdown]
# ## Q4: What is your career goal?

# %% [markdown]
# ![file-treemap (4).jpg](attachment:bb294207-5efc-4cdc-931f-f3c3a07969d4.jpg)
