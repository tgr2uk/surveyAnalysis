# %% [markdown]
# # Sentiment analysis

# %% [markdown]
# ## Analyses
# 1. ~~Simple keyword analysis + tag cloud / bar chart visualisation~~
# 2. ~~Keyword analysis using word embeddings to conflate synonyms~~
#     * Visualization of 2.?
# 3. Sentiment analysis, e.g. pos/neg/neutral etc.
# 4. Clustering of keywords, possibly using Carrot2 or similar
# 5. Compare different cohorts, e.g. based on career stage, geography etc.  (if we have this data).
# 6. Correlation analysis to see how responses are related
#    * e.g. does working longer hours correlate with greater negative sentiment?

# %% [markdown]
# TODO
#
# * ~~Load dataframe~~
# * ~~Apply basic sentiment analysis to column 1~~
#   * ~~do manual check~~
# * ~~Apply SA to all columns~~
# * Test different variations on the SA output, e.g. just use pos?
# * Test different SA algos
# * Programmatically iterate over all columns

# %% [markdown]
# ## Import data, clean & normalise

# %%
import pandas as pd

# %%
# read csv ignoring potential N/As
df = pd.read_csv('Open Ended Questions-Table 1.csv', na_filter = False)

# %%
df
# Out:
#      What are the TWO major challenges faced by embryologists in the workplace?  \
# 0                                                     1
# 1                        Equality with clinical members
# 2                   Bullying by colleagues and managers
# 3           Working hours and too many responsibilities
# 4                                        burnout/stress
# ...                                                 ...
# 1252                                       low salaries
# 1253                                       Low salaries
# 1254  Respect from other departments for the complex...
# 1255                                      limited staff
# 1256                                           Training
#
#                                              Unnamed: 1  \
# 0                                                     2
# 1                                              Poor pay
# 2     Poorly designed protocols, technical ignorance...
# 3                                                Salary
# 4                                       poor management
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254           Financial compensation for overtime etc.
# 1255                                            doctors
# 1256  Being able to have technical and manual capaci...
#
#      What are the TWO major challenges faced by the embryology profession, in general?   \
# 0                                                     1
# 1                             Shortage of trained staff
# 2     Stress of delivering high quality work without...
# 3                                    Access to training
# 4                       not enough highly trained staff
# ...                                                 ...
# 1252                                       low salaries
# 1253                                         Low salary
# 1254             Financial participation: Owning shares
# 1255                                           Salaries
# 1256  There are no university programs for embryolog...
#
#                                              Unnamed: 3  \
# 0                                                     2
# 1                                              Equality
# 2     Presence of narcissistic individuals destroyin...
# 3                                         Certification
# 4                                              politics
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254      lack of respect for the work we do by doctors
# 1255                           Limit work opportunities
# 1256                         costs to be trained abroad
#
#      Provide TWO suggestions to improve embryologists' working conditions  \
# 0                                                     1
# 1                                        Improve number
# 2     Screening for sociopathic personality traits n...
# 3     Add reading and projects into basic workload n...
# 4                                            better pay
# ...                                                 ...
# 1252                                  increase salaries
# 1253                                    Higher salaries
# 1254                                          Pay them!
# 1255                                    Better salaries
# 1256            havng university programs in embryology
#
#                                              Unnamed: 5  \
# 0                                                     2
# 1                                           Improve pay
# 2     Clinics must be staffed so that there is a goo...
# 3     Understand for how many hours a brain can be f...
# 4                              better CPD opportunities
# ...                                                 ...
# 1252                               close over christmas
# 1253                      Close over Christmas holidays
# 1254  Invite financial incentives to the embryologis...
# 1255                             Flexible working hours
# 1256  having fellowships or grants to perform this p...
#
#                               What is your career goal?
# 0                                   Open-Ended Response
# 1                                              Continue
# 2     To survive until retirement without suffering ...
# 3     Get my ESHRE certification  Publish paper thro...
# 4                                               FRCPath
# ...                                                 ...
# 1252                            Dont make a big mistake
# 1253                 Make babies and make people happy.
# 1254  I reached the glass ceiling. All I can do is h...
# 1255                                Laboratory director
# 1256                    being able to help our patients
#
# [1257 rows x 7 columns]

# %%
# create a dict for the short an log column names
long_col_names = {'Q1a': df.columns[0], 'Q1b': df.columns[0], 'Q2a': df.columns[2], 'Q2b': df.columns[2], \
                  'Q3a': df.columns[4], 'Q3b': df.columns[4], 'Q4': df.columns[6]}

# %%
long_col_names
# Out:
# {'Q1a': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q1b': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q2a': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q2b': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q3a': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q3b': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q4': 'What is your career goal?'}

# %%
long_col_names['Q1a']
# Out:
# 'What are the TWO major challenges faced by embryologists in the workplace?'

# %%
# rename the columns
df = df.rename(columns={df.columns[0]: 'Q1a', df.columns[1]: 'Q1b', df.columns[2]: 'Q2a',df.columns[3]: \
                        'Q2b', df.columns[4]: 'Q3a', df.columns[5]: 'Q3b', df.columns[6]: 'Q4'})

# %%
df.columns[0]
# Out:
# 'Q1a'

# %%
# remove first row
df = df.iloc[1:]

# %%
df
# Out:
#                                                     Q1a  \
# 1                        Equality with clinical members
# 2                   Bullying by colleagues and managers
# 3           Working hours and too many responsibilities
# 4                                        burnout/stress
# 5                                           Recognizion
# ...                                                 ...
# 1252                                       low salaries
# 1253                                       Low salaries
# 1254  Respect from other departments for the complex...
# 1255                                      limited staff
# 1256                                           Training
#
#                                                     Q1b  \
# 1                                              Poor pay
# 2     Poorly designed protocols, technical ignorance...
# 3                                                Salary
# 4                                       poor management
# 5                                                 Trust
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254           Financial compensation for overtime etc.
# 1255                                            doctors
# 1256  Being able to have technical and manual capaci...
#
#                                                     Q2a  \
# 1                             Shortage of trained staff
# 2     Stress of delivering high quality work without...
# 3                                    Access to training
# 4                       not enough highly trained staff
# 5                                      Handson training
# ...                                                 ...
# 1252                                       low salaries
# 1253                                         Low salary
# 1254             Financial participation: Owning shares
# 1255                                           Salaries
# 1256  There are no university programs for embryolog...
#
#                                                     Q2b  \
# 1                                              Equality
# 2     Presence of narcissistic individuals destroyin...
# 3                                         Certification
# 4                                              politics
# 5                                                 Trust
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254      lack of respect for the work we do by doctors
# 1255                           Limit work opportunities
# 1256                         costs to be trained abroad
#
#                                                     Q3a  \
# 1                                        Improve number
# 2     Screening for sociopathic personality traits n...
# 3     Add reading and projects into basic workload n...
# 4                                            better pay
# 5                              Good laboratory training
# ...                                                 ...
# 1252                                  increase salaries
# 1253                                    Higher salaries
# 1254                                          Pay them!
# 1255                                    Better salaries
# 1256            havng university programs in embryology
#
#                                                     Q3b  \
# 1                                           Improve pay
# 2     Clinics must be staffed so that there is a goo...
# 3     Understand for how many hours a brain can be f...
# 4                              better CPD opportunities
# 5                                       Troubleshooting
# ...                                                 ...
# 1252                               close over christmas
# 1253                      Close over Christmas holidays
# 1254  Invite financial incentives to the embryologis...
# 1255                             Flexible working hours
# 1256  having fellowships or grants to perform this p...
#
#                                                      Q4
# 1                                              Continue
# 2     To survive until retirement without suffering ...
# 3     Get my ESHRE certification  Publish paper thro...
# 4                                               FRCPath
# 5     Be confident in the work i do  Academically st...
# ...                                                 ...
# 1252                            Dont make a big mistake
# 1253                 Make babies and make people happy.
# 1254  I reached the glass ceiling. All I can do is h...
# 1255                                Laboratory director
# 1256                    being able to help our patients
#
# [1256 rows x 7 columns]

# %%
# create a dictionary to store each of the columns, indexed on the column name
answers = {}
# create a dict of strings to store the column content, indexed on the column name
responses = {}
# iterate over the dataframe columns
for series_name, series in df.items():
    print(series_name)
    print(series)
    answers[series_name] = pd.DataFrame([' '.join(df[series_name].to_list())], columns=['content'])
    responses[series_name] = answers[series_name].values[0,0]
# Out:
# Q1a
# 1                          Equality with clinical members
# 2                     Bullying by colleagues and managers
# 3             Working hours and too many responsibilities
# 4                                          burnout/stress
# 5                                             Recognizion
#                               ...
# 1252                                         low salaries
# 1253                                         Low salaries
# 1254    Respect from other departments for the complex...
# 1255                                        limited staff
# 1256                                             Training
# Name: Q1a, Length: 1256, dtype: object
# Q1b
# 1                                                Poor pay
# 2       Poorly designed protocols, technical ignorance...
# 3                                                  Salary
# 4                                         poor management
# 5                                                   Trust
#                               ...
# 1252                             weekend and holiday work
# 1253                             Weekend and holiday work
# 1254             Financial compensation for overtime etc.
# 1255                                              doctors
# 1256    Being able to have technical and manual capaci...
# Name: Q1b, Length: 1256, dtype: object
# Q2a
# 1                               Shortage of trained staff
# 2       Stress of delivering high quality work without...
# 3                                      Access to training
# 4                         not enough highly trained staff
# 5                                        Handson training
#                               ...
# 1252                                         low salaries
# 1253                                           Low salary
# 1254               Financial participation: Owning shares
# 1255                                             Salaries
# 1256    There are no university programs for embryolog...
# Name: Q2a, Length: 1256, dtype: object
# Q2b
# 1                                                Equality
# 2       Presence of narcissistic individuals destroyin...
# 3                                           Certification
# 4                                                politics
# 5                                                   Trust
#                               ...
# 1252                             weekend and holiday work
# 1253                             Weekend and holiday work
# 1254        lack of respect for the work we do by doctors
# 1255                             Limit work opportunities
# 1256                           costs to be trained abroad
# Name: Q2b, Length: 1256, dtype: object
# Q3a
# 1                                          Improve number
# 2       Screening for sociopathic personality traits n...
# 3       Add reading and projects into basic workload n...
# 4                                              better pay
# 5                                Good laboratory training
#                               ...
# 1252                                    increase salaries
# 1253                                      Higher salaries
# 1254                                            Pay them!
# 1255                                      Better salaries
# 1256              havng university programs in embryology
# Name: Q3a, Length: 1256, dtype: object
# Q3b
# 1                                             Improve pay
# 2       Clinics must be staffed so that there is a goo...
# 3       Understand for how many hours a brain can be f...
# 4                                better CPD opportunities
# 5                                         Troubleshooting
#                               ...
# 1252                                 close over christmas
# 1253                        Close over Christmas holidays
# 1254    Invite financial incentives to the embryologis...
# 1255                               Flexible working hours
# 1256    having fellowships or grants to perform this p...
# Name: Q3b, Length: 1256, dtype: object
# Q4
# 1                                                Continue
# 2       To survive until retirement without suffering ...
# 3       Get my ESHRE certification  Publish paper thro...
# 4                                                 FRCPath
# 5       Be confident in the work i do  Academically st...
#                               ...
# 1252                              Dont make a big mistake
# 1253                   Make babies and make people happy.
# 1254    I reached the glass ceiling. All I can do is h...
# 1255                                  Laboratory director
# 1256                      being able to help our patients
# Name: Q4, Length: 1256, dtype: object

# %%
responses['Q1a']
# Out:
# 'Equality with clinical members Bullying by colleagues and managers Working hours and too many responsibilities burnout/stress Recognizion Stress created by no embryos/ less embryos/ poor quality embryos General workplace politics Burnout due to working continously through weekends without breaks fertilization outcomes are laid on the embryologists lack of leadership Recognition of our contribution in the ART field Time managment administration work work overload Time spent at work Workload Overworked Oocyte quality hard cases; bad sperm, fragile oocytes We are not being paid fairly (it\'s a specialized field) Biopsy Poor pay; lack of transparency of salary in the private sector time management with patients/doctors Pression Daily work hours and weekends Employees shortage Stress induced work environment Recognition and sallary make no mistake space space Never ever make a mistake Workload BURN OUT Repeated manual processes emotional stress A good salary Heavy workload Scientific Recognition Little black of communication with clinical team lack of staff Automaticity Financial Restrictions Inconsistent workload Stress TRUST Work overload Staffing levels Lack of a voice Poor management Staff retention / salary MULTITASKING Understaffing Little or no day off alloted Each and every case of ours is different it itself is a big challenge. pregnancy status- if negative, we are blamed Lack of staff Work pressures stress Working for extended periods without a break Burnout Excessive overtime Stress (Burn Out) Keeping up with technological advancements Bad management huge responsibility high workload Burn-out Negative result blame comes on embryologist maintenance of equipment Communication with physicians documentation High workload Underpaid Workload it\'s time sensitive job Work load/ complexity of cases Shortage of staff: lack of assistance Time sensitivity Too much workload Staff shortage Overworked Workload and recognition Colleagues bad  behavior,  mental harassment The increased biopsie cases Burnout/overtime Salary designation Respect from others medical specialities Less salary Long hours Physical stress Overworked To be recognized Short staffing Data report Maintaining sterile conditions I don\'t know why it\'s so hard in India , here doctor don\'t accept the case of poor quality eggs., They want 100% fertilization in that case Time Schedule low budget Pressure to perform perfectly on both standard and sensitive cases Burnout Work time Lack of recognition Wagner, remuneration Good payment Correct staff number per procedures Quality control engagment for all in lab and clinic New technologies Salary Payment Lack of recognition ICSI less no. of cycles Paper work burden Less staffing Work condition in-adequate pay Staff shortage No flexible timing Too much work Equipments issues Timing Short staffing Too few staff A increase in work load underappreciation Undermining the competence level of the embryologist by the clinician Work overload Workload Burn out from stress/lack of support High pressure environment Pay Staffing High workloads Staffing Burn out Stress over work Clinical pressure Emotional stress stress sufficient staffing Getting appropriate training Distraction time management Lots of Time pressure & poor life work balance Lack of appreciation Staffing shortages Low salary Difficulty in recruiting trained embryologists Low income profession Lack of staff Stress dealing with some patients understaff Fatigue Understaffing Working outside normal hours High stress job Technical training Training Toxic work environment Sometimes, lack of coordination within the Embryologist team  Lack of more innovative equipment Expected to know all the answers (even for other departments eg medications and scanning dates) less equipment Doctors timing Workload Retraining are expensive Salary Control by the clinicians Staffing levels Time personal growth Verification of identity and managing unnecessary paperwork Embryo decisions Overworki ...

# %%
# lower case
for col_name in responses:
    responses[col_name] = responses[col_name].casefold()

# %% [markdown]
# ## Sentiment Analysis using NLTK

# %% [markdown]
# See https://www.datacamp.com/tutorial/text-analytics-beginners-nltk

# %%
# import libraries
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
df['Q1a']
# Out:
# 1                          Equality with clinical members
# 2                     Bullying by colleagues and managers
# 3             Working hours and too many responsibilities
# 4                                          burnout/stress
# 5                                             Recognizion
#                               ...
# 1252                                         low salaries
# 1253                                         Low salaries
# 1254    Respect from other departments for the complex...
# 1255                                        limited staff
# 1256                                             Training
# Name: Q1a, Length: 1256, dtype: object

# %%
# create preprocess_text function
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())
    
    # Remove stop words
    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]
   
    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    # Join the tokens back into a string
    processed_text = ' '.join(lemmatized_tokens)
    return processed_text

# %%
df['Q1a'] = df['Q1a'].apply(preprocess_text)
df
# Out:
#                                    Q1a  \
# 1             equality clinical member
# 2           bullying colleague manager
# 3     working hour many responsibility
# 4                       burnout/stress
# 5                          recognizion
# ...                                ...
# 1252                        low salary
# 1253                        low salary
# 1254   respect department complex work
# 1255                     limited staff
# 1256                          training
#
#                                                     Q1b  \
# 1                                              Poor pay
# 2     Poorly designed protocols, technical ignorance...
# 3                                                Salary
# 4                                       poor management
# 5                                                 Trust
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254           Financial compensation for overtime etc.
# 1255                                            doctors
# 1256  Being able to have technical and manual capaci...
#
#                                                     Q2a  \
# 1                             Shortage of trained staff
# 2     Stress of delivering high quality work without...
# 3                                    Access to training
# 4                       not enough highly trained staff
# 5                                      Handson training
# ...                                                 ...
# 1252                                       low salaries
# 1253                                         Low salary
# 1254             Financial participation: Owning shares
# 1255                                           Salaries
# 1256  There are no university programs for embryolog...
#
#                                                     Q2b  \
# 1                                              Equality
# 2     Presence of narcissistic individuals destroyin...
# 3                                         Certification
# 4                                              politics
# 5                                                 Trust
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254      lack of respect for the work we do by doctors
# 1255                           Limit work opportunities
# 1256                         costs to be trained abroad
#
#                                                     Q3a  \
# 1                                        Improve number
# 2     Screening for sociopathic personality traits n...
# 3     Add reading and projects into basic workload n...
# 4                                            better pay
# 5                              Good laboratory training
# ...                                                 ...
# 1252                                  increase salaries
# 1253                                    Higher salaries
# 1254                                          Pay them!
# 1255                                    Better salaries
# 1256            havng university programs in embryology
#
#                                                     Q3b  \
# 1                                           Improve pay
# 2     Clinics must be staffed so that there is a goo...
# 3     Understand for how many hours a brain can be f...
# 4                              better CPD opportunities
# 5                                       Troubleshooting
# ...                                                 ...
# 1252                               close over christmas
# 1253                      Close over Christmas holidays
# 1254  Invite financial incentives to the embryologis...
# 1255                             Flexible working hours
# 1256  having fellowships or grants to perform this p...
#
#                                                      Q4
# 1                                              Continue
# 2     To survive until retirement without suffering ...
# 3     Get my ESHRE certification  Publish paper thro...
# 4                                               FRCPath
# 5     Be confident in the work i do  Academically st...
# ...                                                 ...
# 1252                            Dont make a big mistake
# 1253                 Make babies and make people happy.
# 1254  I reached the glass ceiling. All I can do is h...
# 1255                                Laboratory director
# 1256                    being able to help our patients
#
# [1256 rows x 7 columns]

# %%
# initialize NLTK sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# BINARY get_sentiment function
def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    sentiment = 1 if scores['pos'] > 0 else 0
    return sentiment

# %%
# compound get_sentiment function
def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    return scores['compound']

# %%
df['sentiment'] = df['Q1a'].apply(get_sentiment)

# %%
from keybert import KeyBERT

# %%
doc = responses['Q1a']

# %%
kw_model = KeyBERT()
keywords = kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 2), stop_words=None)
print(keywords)

# %%
keywords = kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 2))
print(keywords)

# %%
# To diversify the results, we take the 2 x top_n most similar words/phrases to the document. Then, we take all top_n combinations 
# from the 2 x top_n words and extract the combination that are the least similar to each other by cosine similarity.

kw_model.extract_keywords(doc, keyphrase_ngram_range=(2, 3), stop_words='english',
                              use_maxsum=True, nr_candidates=20, top_n=10)

# %%
# To diversify the results, we can use Maximal Margin Relevance (MMR) to create keywords / keyphrases which is 
# also based on cosine similarity. The results with high diversity:

kw_model.extract_keywords(doc, keyphrase_ngram_range=(2, 3), stop_words='english',
                          use_mmr=True, diversity=0.7, top_n=10)

# %%
#  Guided KeyBERT

seed_keywords = ["workload"]
kw_model.extract_keywords(doc, seed_keywords=seed_keywords, keyphrase_ngram_range=(2, 3), stop_words='english')

# %% [markdown]
# ## Prepare embeddings

# %%
doc_embeddings, word_embeddings = kw_model.extract_embeddings(doc, keyphrase_ngram_range=(2, 3), stop_words='english')

# %%
kw_model.extract_keywords(doc, doc_embeddings=doc_embeddings, word_embeddings=word_embeddings, keyphrase_ngram_range=(2, 3), stop_words='english')

# %% [markdown]
# ## Generate keywords for all 7 verbatims

# %%
for col_name in responses:
    print(long_col_names[col_name])
    keywords = kw_model.extract_keywords(responses[col_name], keyphrase_ngram_range=(2, 4), stop_words='english', use_mmr=True, diversity=0.7, top_n=10)
    print(keywords, "\n")

# %%
with pd.option_context('display.max_colwidth', None):
  display(df[['Q1a', 'sentiment']])
# Out:
#                                                             Q1a  sentiment
# 1                                Equality with clinical members     0.0000
# 2                           Bullying by colleagues and managers    -0.5994
# 3                   Working hours and too many responsibilities     0.0000
# 4                                                burnout/stress     0.0000
# 5                                                   Recognizion     0.0000
# ...                                                         ...        ...
# 1252                                               low salaries    -0.2732
# 1253                                               Low salaries    -0.2732
# 1254  Respect from other departments for the complex work we do     0.4767
# 1255                                              limited staff    -0.2263
# 1256                                                   Training     0.0000
#
# [1256 rows x 2 columns]

# %%
df['sentiment'] = df['Q1b'].apply(get_sentiment)

# %%
with pd.option_context('display.max_colwidth', None):
  display(df[['Q1b', 'sentiment']])
# Out:
#                                                                               Q1b  \
# 1                                                                        Poor pay
# 2     Poorly designed protocols, technical ignorance by colleagues and managers.
# 3                                                                          Salary
# 4                                                                 poor management
# 5                                                                           Trust
# ...                                                                           ...
# 1252                                                     weekend and holiday work
# 1253                                                     Weekend and holiday work
# 1254                                     Financial compensation for overtime etc.
# 1255                                                                      doctors
# 1256                           Being able to have technical and manual capacities
#
#       sentiment
# 1       -0.5423
# 2       -0.3612
# 3        0.0000
# 4       -0.4767
# 5        0.5106
# ...         ...
# 1252     0.4019
# 1253     0.4019
# 1254     0.0000
# 1255     0.0000
# 1256     0.0000
#
# [1256 rows x 2 columns]

# %%
df['sentiment'] = df['Q2a'].apply(get_sentiment)
with pd.option_context('display.max_colwidth', None):
  display(df[['Q2a', 'sentiment']])
# Out:
#                                                                    Q2a  \
# 1                                            Shortage of trained staff
# 2     Stress of delivering high quality work without sufficient staff.
# 3                                                   Access to training
# 4                                      not enough highly trained staff
# 5                                                     Handson training
# ...                                                                ...
# 1252                                                      low salaries
# 1253                                                        Low salary
# 1254                            Financial participation: Owning shares
# 1255                                                          Salaries
# 1256               There are no university programs for embryologiests
#
#       sentiment
# 1       -0.2500
# 2       -0.4215
# 3        0.0000
# 4        0.0000
# 5        0.0000
# ...         ...
# 1252    -0.2732
# 1253    -0.2732
# 1254     0.2960
# 1255     0.0000
# 1256    -0.2960
#
# [1256 rows x 2 columns]

# %%
df['sentiment'] = df['Q2b'].apply(get_sentiment)
with pd.option_context('display.max_colwidth', None):
  display(df[['Q2b', 'sentiment']])
# Out:
#                                                                                Q2b  \
# 1                                                                         Equality
# 2     Presence of narcissistic individuals destroying mental health of colleagues.
# 3                                                                    Certification
# 4                                                                         politics
# 5                                                                            Trust
# ...                                                                            ...
# 1252                                                      weekend and holiday work
# 1253                                                      Weekend and holiday work
# 1254                                 lack of respect for the work we do by doctors
# 1255                                                      Limit work opportunities
# 1256                                                    costs to be trained abroad
#
#       sentiment
# 1        0.0000
# 2       -0.5574
# 3        0.0000
# 4        0.0000
# 5        0.5106
# ...         ...
# 1252     0.4019
# 1253     0.4019
# 1254     0.2023
# 1255     0.3818
# 1256     0.0000
#
# [1256 rows x 2 columns]

# %%
df['sentiment'] = df['Q3a'].apply(get_sentiment)
with pd.option_context('display.max_colwidth', None):
  display(df[['Q3a', 'sentiment']])
# Out:
#                                                                                                                                                  Q3a  \
# 1                                                                                                                                     Improve number
# 2     Screening for sociopathic personality traits needs to be introduced.  A 45 minute interview is no way to select for entry into the profession.
# 3                                                                                   Add reading and projects into basic workload not in leisure time
# 4                                                                                                                                         better pay
# 5                                                                                                                           Good laboratory training
# ...                                                                                                                                              ...
# 1252                                                                                                                               increase salaries
# 1253                                                                                                                                 Higher salaries
# 1254                                                                                                                                       Pay them!
# 1255                                                                                                                                 Better salaries
# 1256                                                                                                         havng university programs in embryology
#
#       sentiment
# 1        0.4939
# 2       -0.2960
# 3        0.0000
# 4        0.3612
# 5        0.4404
# ...         ...
# 1252     0.3182
# 1253     0.0000
# 1254    -0.1759
# 1255     0.4404
# 1256     0.0000
#
# [1256 rows x 2 columns]

# %%
df['sentiment'] = df['Q3b'].apply(get_sentiment)
with pd.option_context('display.max_colwidth', None):
  display(df[['Q3b', 'sentiment']])
# Out:
#                                                                                                                                                  Q3b  \
# 1                                                                                                                                        Improve pay
# 2     Clinics must be staffed so that there is a good margin of available workers so that staff are not pressured to work at 110% and then burn out.
# 3                                                          Understand for how many hours a brain can be functional performing lab procedures per day
# 4                                                                                                                           better CPD opportunities
# 5                                                                                                                                    Troubleshooting
# ...                                                                                                                                              ...
# 1252                                                                                                                            close over christmas
# 1253                                                                                                                   Close over Christmas holidays
# 1254                                                                          Invite financial incentives to the embryologists as well. e.g. Shares!
# 1255                                                                                                                          Flexible working hours
# 1256                                                                                           having fellowships or grants to perform this programs
#
#       sentiment
# 1        0.3612
# 2        0.5523
# 3        0.0000
# 4        0.6705
# 5        0.1779
# ...         ...
# 1252     0.0000
# 1253     0.3818
# 1254     0.7574
# 1255     0.2263
# 1256     0.2263
#
# [1256 rows x 2 columns]

# %%
df['sentiment'] = df['Q4'].apply(get_sentiment)
with pd.option_context('display.max_colwidth', None):
  display(df[['Q4', 'sentiment']])
# Out:
#                                                                                                                                    Q4  \
# 1                                                                                                                            Continue
# 2                                    To survive until retirement without suffering mental illness or making a catestrophic lab error.
# 3     Get my ESHRE certification  Publish paper through research   Presentations and leading workshops   Acquire lab directing skills
# 4                                                                                                                             FRCPath
# 5                                                                                  Be confident in the work i do  Academically strong
# ...                                                                                                                               ...
# 1252                                                                                                          Dont make a big mistake
# 1253                                                                                               Make babies and make people happy.
# 1254                                  I reached the glass ceiling. All I can do is hope to study further and further and further.....
# 1255                                                                                                              Laboratory director
# 1256                                                                                                  being able to help our patients
#
#       sentiment
# 1        0.0000
# 2        0.2760
# 3        0.0000
# 4        0.0000
# 5        0.7579
# ...         ...
# 1252     0.2584
# 1253     0.5719
# 1254     0.5106
# 1255     0.0000
# 1256     0.4019
#
# [1256 rows x 2 columns]

# %% [markdown]
# ## Iterate over all columns

# %%
for col_name, col in df.items():
    print(col_name)
    # print(series)
    col.apply(get_sentiment)
# Out:
# Q1a
# Q1b
# Q2a
# Q2b
# Q3a
# Q3b
# Q4
# sentiment
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 4
#       2 print(col_name)
#       3 # print(series)
# ----> 4 col.apply(get_sentiment)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[81], line 3, in get_sentiment(text)
#       2 def get_sentiment(text):
# ----> 3     scores = analyzer.polarity_scores(text)
#       4     return scores['compound']
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/nltk/sentiment/vader.py:366, in SentimentIntensityAnalyzer.polarity_scores(self, text)
#     355 """
#     356 Return a float for sentiment strength based on the input text.
#     357 Positive values are positive valence, negative value are negative
#    (...)
#     363     matched as if it was a normal word in the sentence.
#     364 """
#     365 # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
# --> 366 sentitext = SentiText(
#     367     text, self.constants.PUNC_LIST, self.constants.REGEX_REMOVE_PUNCTUATION
#     368 )
#     369 sentiments = []
#     370 words_and_emoticons = sentitext.words_and_emoticons
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/nltk/sentiment/vader.py:270, in SentiText.__init__(self, text, punc_list, regex_remove_punctuation)
#     268 def __init__(self, text, punc_list, regex_remove_punctuation):
#     269     if not isinstance(text, str):
# --> 270         text = str(text.encode("utf-8"))
#     271     self.text = text
#     272     self.PUNC_LIST = punc_list
#
# AttributeError: 'float' object has no attribute 'encode'
