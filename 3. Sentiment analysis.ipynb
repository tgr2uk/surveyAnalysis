# %% [markdown]
# # Sentiment analysis

# %% [markdown]
# ## Analyses
# 1. ~~Simple keyword analysis~~
#     * ~~tag cloud / bar chart visualisation~~
# 3. ~~Keyword analysis using word embeddings to conflate synonyms~~
#     * Visualization of 2.?
# 4. ~~Sentiment analysis, e.g. pos/neg/neutral etc.~~
# 6. Compare different cohorts, e.g. based on career stage, geography etc.  (if we have this data).
#    * ~~Need to prioritise stratifications~~
# 5. Clustering of keywords, possibly using Carrot2 or similar?
# 7. Correlation analysis to see how responses are related
#    * e.g. does working longer hours correlate with greater negative sentiment?

# %% [markdown]
# TODO
#
# * ~~Load dataframe~~
# * ~~Apply basic sentiment analysis to column 1~~
#   * ~~do manual check~~
# * ~~Apply SA to all columns~~
# * ~~calculate average sentiment for each column~~
#     * Experiment with variations on the VADER output, e.g. use other sentiment values (e.g. pos/neg)
# * Programmatically iterate over all columns
# * Test different SA algos
#   * e.g. https://realpython.com/python-nltk-sentiment-analysis/
#   * Can't really use ML without training data

# %% [markdown]
# ## Prioritised stratifications
# 1. Geography
#    * low income
#    * low/middle
#    * high
# 2. Gender
#    * male
#    * female
# 3. Role
#    * student/intern/trainee
#    * technician/assistant
#    * embryologist/technologist/clinical scientist/andrologist/freelance
#    * chief/lead/senior embryologist
#    * directors/managers
#    * others

# %% [markdown]
# ## SA hypotheses:
# * Type of unit: Public sector more positive than private?
# * Gender: no difference expected
# * Geography: higher income more negative?
# * Role: more senior is more negative?

# %% [markdown]
# ## Import data, clean & normalise

# %%
import pandas as pd

# %%
# read csv ignoring potential N/As
df = pd.read_csv('Open Ended Questions-Table 1.csv', na_filter = False)

# %%
df
# Out:
#      What are the TWO major challenges faced by embryologists in the workplace?  \
# 0                                                     1
# 1                        Equality with clinical members
# 2                   Bullying by colleagues and managers
# 3           Working hours and too many responsibilities
# 4                                        burnout/stress
# ...                                                 ...
# 1252                                       low salaries
# 1253                                       Low salaries
# 1254  Respect from other departments for the complex...
# 1255                                      limited staff
# 1256                                           Training
#
#                                              Unnamed: 1  \
# 0                                                     2
# 1                                              Poor pay
# 2     Poorly designed protocols, technical ignorance...
# 3                                                Salary
# 4                                       poor management
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254           Financial compensation for overtime etc.
# 1255                                            doctors
# 1256  Being able to have technical and manual capaci...
#
#      What are the TWO major challenges faced by the embryology profession, in general?   \
# 0                                                     1
# 1                             Shortage of trained staff
# 2     Stress of delivering high quality work without...
# 3                                    Access to training
# 4                       not enough highly trained staff
# ...                                                 ...
# 1252                                       low salaries
# 1253                                         Low salary
# 1254             Financial participation: Owning shares
# 1255                                           Salaries
# 1256  There are no university programs for embryolog...
#
#                                              Unnamed: 3  \
# 0                                                     2
# 1                                              Equality
# 2     Presence of narcissistic individuals destroyin...
# 3                                         Certification
# 4                                              politics
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254      lack of respect for the work we do by doctors
# 1255                           Limit work opportunities
# 1256                         costs to be trained abroad
#
#      Provide TWO suggestions to improve embryologists' working conditions  \
# 0                                                     1
# 1                                        Improve number
# 2     Screening for sociopathic personality traits n...
# 3     Add reading and projects into basic workload n...
# 4                                            better pay
# ...                                                 ...
# 1252                                  increase salaries
# 1253                                    Higher salaries
# 1254                                          Pay them!
# 1255                                    Better salaries
# 1256            havng university programs in embryology
#
#                                              Unnamed: 5  \
# 0                                                     2
# 1                                           Improve pay
# 2     Clinics must be staffed so that there is a goo...
# 3     Understand for how many hours a brain can be f...
# 4                              better CPD opportunities
# ...                                                 ...
# 1252                               close over christmas
# 1253                      Close over Christmas holidays
# 1254  Invite financial incentives to the embryologis...
# 1255                             Flexible working hours
# 1256  having fellowships or grants to perform this p...
#
#                               What is your career goal?
# 0                                   Open-Ended Response
# 1                                              Continue
# 2     To survive until retirement without suffering ...
# 3     Get my ESHRE certification  Publish paper thro...
# 4                                               FRCPath
# ...                                                 ...
# 1252                            Dont make a big mistake
# 1253                 Make babies and make people happy.
# 1254  I reached the glass ceiling. All I can do is h...
# 1255                                Laboratory director
# 1256                    being able to help our patients
#
# [1257 rows x 7 columns]

# %%
# create a dict for the short and log column names
long_col_names = {'Q1a': df.columns[0], 'Q1b': df.columns[0], 'Q2a': df.columns[2], 'Q2b': df.columns[2], \
                  'Q3a': df.columns[4], 'Q3b': df.columns[4], 'Q4': df.columns[6]}

# %%
long_col_names
# Out:
# {'Q1a': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q1b': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q2a': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q2b': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q3a': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q3b': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q4': 'What is your career goal?'}

# %%
long_col_names['Q1a']
# Out:
# 'What are the TWO major challenges faced by embryologists in the workplace?'

# %%
# rename the columns
df = df.rename(columns={df.columns[0]: 'Q1a', df.columns[1]: 'Q1b', df.columns[2]: 'Q2a',df.columns[3]: \
                        'Q2b', df.columns[4]: 'Q3a', df.columns[5]: 'Q3b', df.columns[6]: 'Q4'})

# %%
df.columns[0]
# Out:
# 'Q1a'

# %%
# remove first row
df = df.iloc[1:]

# %%
df
# Out:
#                                                     Q1a  \
# 1                        Equality with clinical members
# 2                   Bullying by colleagues and managers
# 3           Working hours and too many responsibilities
# 4                                        burnout/stress
# 5                                           Recognizion
# ...                                                 ...
# 1252                                       low salaries
# 1253                                       Low salaries
# 1254  Respect from other departments for the complex...
# 1255                                      limited staff
# 1256                                           Training
#
#                                                     Q1b  \
# 1                                              Poor pay
# 2     Poorly designed protocols, technical ignorance...
# 3                                                Salary
# 4                                       poor management
# 5                                                 Trust
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254           Financial compensation for overtime etc.
# 1255                                            doctors
# 1256  Being able to have technical and manual capaci...
#
#                                                     Q2a  \
# 1                             Shortage of trained staff
# 2     Stress of delivering high quality work without...
# 3                                    Access to training
# 4                       not enough highly trained staff
# 5                                      Handson training
# ...                                                 ...
# 1252                                       low salaries
# 1253                                         Low salary
# 1254             Financial participation: Owning shares
# 1255                                           Salaries
# 1256  There are no university programs for embryolog...
#
#                                                     Q2b  \
# 1                                              Equality
# 2     Presence of narcissistic individuals destroyin...
# 3                                         Certification
# 4                                              politics
# 5                                                 Trust
# ...                                                 ...
# 1252                           weekend and holiday work
# 1253                           Weekend and holiday work
# 1254      lack of respect for the work we do by doctors
# 1255                           Limit work opportunities
# 1256                         costs to be trained abroad
#
#                                                     Q3a  \
# 1                                        Improve number
# 2     Screening for sociopathic personality traits n...
# 3     Add reading and projects into basic workload n...
# 4                                            better pay
# 5                              Good laboratory training
# ...                                                 ...
# 1252                                  increase salaries
# 1253                                    Higher salaries
# 1254                                          Pay them!
# 1255                                    Better salaries
# 1256            havng university programs in embryology
#
#                                                     Q3b  \
# 1                                           Improve pay
# 2     Clinics must be staffed so that there is a goo...
# 3     Understand for how many hours a brain can be f...
# 4                              better CPD opportunities
# 5                                       Troubleshooting
# ...                                                 ...
# 1252                               close over christmas
# 1253                      Close over Christmas holidays
# 1254  Invite financial incentives to the embryologis...
# 1255                             Flexible working hours
# 1256  having fellowships or grants to perform this p...
#
#                                                      Q4
# 1                                              Continue
# 2     To survive until retirement without suffering ...
# 3     Get my ESHRE certification  Publish paper thro...
# 4                                               FRCPath
# 5     Be confident in the work i do  Academically st...
# ...                                                 ...
# 1252                            Dont make a big mistake
# 1253                 Make babies and make people happy.
# 1254  I reached the glass ceiling. All I can do is h...
# 1255                                Laboratory director
# 1256                    being able to help our patients
#
# [1256 rows x 7 columns]

# %% [markdown]
# ## Aggregate all the responses for visualization

# %%
# create a dictionary to store each of the columns, indexed on the column name
answers = {}
# create a dict of strings to store the column content, indexed on the column name
responses = {}
# iterate over the dataframe columns
for series_name, series in df.items():
    print(series_name)
    print(series)
    answers[series_name] = pd.DataFrame([' '.join(df[series_name].to_list())], columns=['content'])
    responses[series_name] = answers[series_name].values[0,0]
# Out:
# Q1a
# 1                         Equality with clinical members
# 2            Working hours and too many responsibilities
# 3                                         burnout/stress
# 4                                            Recognizion
# 5                             General workplace politics
#                              ...
# 853                                         Low Salaries
# 854                                         low salaries
# 855                                         Low salaries
# 856    Respect from other departments for the complex...
# 857                                        limited staff
# Name: Q1a, Length: 857, dtype: object
# Q1b
# 1                                      Poor pay
# 2                                        Salary
# 3                               poor management
# 4                                         Trust
# 5                             Internal Pressure
#                          ...
# 853                            Working weekends
# 854                    weekend and holiday work
# 855                    Weekend and holiday work
# 856    Financial compensation for overtime etc.
# 857                                     doctors
# Name: Q1b, Length: 857, dtype: object
# Q2a
# 1                   Shortage of trained staff
# 2                          Access to training
# 3             not enough highly trained staff
# 4                            Handson training
# 5                                 Undervalued
#                         ...
# 853                 Not closing over December
# 854                              low salaries
# 855                                Low salary
# 856    Financial participation: Owning shares
# 857                                  Salaries
# Name: Q2a, Length: 857, dtype: object
# Q2b
# 1                                           Equality
# 2                                      Certification
# 3                                           politics
# 4                                              Trust
# 5                                          Underpaid
#                            ...
# 853                                     Low Salaries
# 854                         weekend and holiday work
# 855                         Weekend and holiday work
# 856    lack of respect for the work we do by doctors
# 857                         Limit work opportunities
# Name: Q2b, Length: 857, dtype: object
# Q3a
# 1                                         Improve number
# 2      Add reading and projects into basic workload n...
# 3                                             better pay
# 4                               Good laboratory training
# 5                        Flexible hours to reduce stress
#                              ...
# 853                                      Higher salaries
# 854                                    increase salaries
# 855                                      Higher salaries
# 856                                            Pay them!
# 857                                      Better salaries
# Name: Q3a, Length: 857, dtype: object
# Q3b
# 1                                            Improve pay
# 2      Understand for how many hours a brain can be f...
# 3                               better CPD opportunities
# 4                                        Troubleshooting
# 5                           Shorter rotations in the Lab
#                              ...
# 853                                Closing over December
# 854                                 close over christmas
# 855                        Close over Christmas holidays
# 856    Invite financial incentives to the embryologis...
# 857                               Flexible working hours
# Name: Q3b, Length: 857, dtype: object
# Q4
# 1                                               Continue
# 2      Get my ESHRE certification  Publish paper thro...
# 3                                                FRCPath
# 4      Be confident in the work i do  Academically st...
# 5      I would like to work as an embryologist intern...
#                              ...
# 853    To complete my masters and become the best pra...
# 854                              Dont make a big mistake
# 855                   Make babies and make people happy.
# 856    I reached the glass ceiling. All I can do is h...
# 857                                  Laboratory director
# Name: Q4, Length: 857, dtype: object

# %%
responses['Q1a']
# Out:
# 'Equality with clinical members Working hours and too many responsibilities burnout/stress Recognizion General workplace politics Burnout due to working continously through weekends without breaks fertilization outcomes are laid on the embryologists Recognition of our contribution in the ART field Time managment administration work Overworked Oocyte quality hard cases; bad sperm, fragile oocytes Poor pay; lack of transparency of salary in the private sector time management with patients/doctors Pression Daily work hours and weekends Employees shortage space space Never ever make a mistake Workload BURN OUT Repeated manual processes emotional stress A good salary Little black of communication with clinical team Automaticity Financial Restrictions Inconsistent workload TRUST Work overload Staffing levels Staff retention / salary MULTITASKING Understaffing Little or no day off alloted Each and every case of ours is different it itself is a big challenge. pregnancy status- if negative, we are blamed Work pressures stress Working for extended periods without a break Excessive overtime Stress (Burn Out) Keeping up with technological advancements Bad management huge responsibility high workload Burn-out Negative result blame comes on embryologist Communication with physicians High workload Underpaid Work load/ complexity of cases Shortage of staff: lack of assistance Time sensitivity Too much workload Staff shortage Overworked Workload and recognition Colleagues bad  behavior,  mental harassment The increased biopsie cases Burnout/overtime Respect from others medical specialities Less salary Physical stress To be recognized Short staffing Data report I don\'t know why it\'s so hard in India , here doctor don\'t accept the case of poor quality eggs., They want 100% fertilization in that case  Pressure to perform perfectly on both standard and sensitive cases Burnout Work time Lack of recognition Wagner, remuneration Correct staff number per procedures Quality control engagment for all in lab and clinic New technologies Salary Payment Lack of recognition less no. of cycles Paper work burden Less staffing Staff shortage No flexible timing Short staffing Too few staff A increase in work load Work overload Workload Burn out from stress/lack of support High pressure environment Pay Staffing High workloads Staffing Stress Emotional stress stress Getting appropriate training Distraction time management Lack of appreciation Staffing shortages Low salary Difficulty in recruiting trained embryologists Low income profession Lack of staff Stress dealing with some patients understaff Fatigue Understaffing Working outside normal hours High stress job Sometimes, lack of coordination within the Embryologist team  Lack of more innovative equipment Expected to know all the answers (even for other departments eg medications and scanning dates) less equipment Doctors timing Embryo decisions Overworking for long periods Organisation Shortage of time to perform additional duties along with clinical work Working on weekends Financial burden No proper and systematic training , relay on senior training and ongoing self study Cannot participate in making desicions regarding the embryos Communication between clinicians and embryologists Lack of autonomy Dominance of clinicians Paperwork Short staff The Expectations from practice clinicians to perform unstoppable with low wedges their IVF lab Under staff Workload Long leave for vacation Overworked Training facilities available Overworked Stress due to high workload working highly concentrated in stressful conditions Tiredness technical capacity Clinicians interference Promising outcome for poor quality oocyte and sperm Cooperation and Understanding from ObGs Lack of proper resources Work/life balance Clinician stress Keeping up to date Workload Need better work recognition from management Heavy work load Na Senior junior problem Limited resources Pressure to perform unethical practices by the clinician To use th ...

# %%
# lower case
for col_name in responses:
    responses[col_name] = responses[col_name].casefold()

# %% [markdown]
# ## Sentiment Analysis using NLTK

# %% [markdown]
# See https://www.datacamp.com/tutorial/text-analytics-beginners-nltk

# %%
# import libraries
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
df['Q1a']
# Out:
# 1                          Equality with clinical members
# 2                     Bullying by colleagues and managers
# 3             Working hours and too many responsibilities
# 4                                          burnout/stress
# 5                                             Recognizion
#                               ...
# 1252                                         low salaries
# 1253                                         Low salaries
# 1254    Respect from other departments for the complex...
# 1255                                        limited staff
# 1256                                             Training
# Name: Q1a, Length: 1256, dtype: object

# %%
# create preprocess_text function
def preprocess_text(text):
    # Tokenize the text
    tokens = word_tokenize(text.lower())
    
    # Remove stop words
    filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]
   
    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

    # Join the tokens back into a string
    processed_text = ' '.join(lemmatized_tokens)
    return processed_text

# %%
# Pre-processing made things worse on test data (see SA test.ipynb)

# df['Q1a'] = df['Q1a'].apply(preprocess_text)
# df

# %%
# initialize NLTK sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# BINARY get_sentiment function
def get_binary_sentiment(text):
    scores = analyzer.polarity_scores(text)
    sentiment = 1 if scores['pos'] > 0 else 0
    return sentiment

# %%
# compound get_sentiment function
def get_compound_sentiment(text):
    scores = analyzer.polarity_scores(text)
    return scores['compound']

# %%
# vanilla get_sentiment function
def get_sentiment(text):
    scores = analyzer.polarity_scores(text)
    return scores

# %%
col='Q1a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by embryologists in the workplace?
#                                                             Q1a  sentiment
# 1                                Equality with clinical members     0.0000
# 2                           Bullying by colleagues and managers    -0.5994
# 3                   Working hours and too many responsibilities     0.0000
# 4                                                burnout/stress     0.0000
# 5                                                   Recognizion     0.0000
# ...                                                         ...        ...
# 1252                                               low salaries    -0.2732
# 1253                                               Low salaries    -0.2732
# 1254  Respect from other departments for the complex work we do     0.4767
# 1255                                              limited staff    -0.2263
# 1256                                                   Training     0.0000
#
# [1256 rows x 2 columns]
# Average sentiment: -0.045
# Std dev:            0.240

# %%
col='Q1b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by embryologists in the workplace?
#                                                                               Q1b  \
# 1                                                                        Poor pay
# 2     Poorly designed protocols, technical ignorance by colleagues and managers.
# 3                                                                          Salary
# 4                                                                 poor management
# 5                                                                           Trust
# ...                                                                           ...
# 1252                                                     weekend and holiday work
# 1253                                                     Weekend and holiday work
# 1254                                     Financial compensation for overtime etc.
# 1255                                                                      doctors
# 1256                           Being able to have technical and manual capacities
#
#       sentiment
# 1       -0.5423
# 2       -0.3612
# 3        0.0000
# 4       -0.4767
# 5        0.5106
# ...         ...
# 1252     0.4019
# 1253     0.4019
# 1254     0.0000
# 1255     0.0000
# 1256     0.0000
#
# [1256 rows x 2 columns]
# Average sentiment: -0.051
# Std dev:            0.245

# %%
col='Q2a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by the embryology profession, in general?
#                                                                    Q2a  \
# 1                                            Shortage of trained staff
# 2     Stress of delivering high quality work without sufficient staff.
# 3                                                   Access to training
# 4                                      not enough highly trained staff
# 5                                                     Handson training
# ...                                                                ...
# 1252                                                      low salaries
# 1253                                                        Low salary
# 1254                            Financial participation: Owning shares
# 1255                                                          Salaries
# 1256               There are no university programs for embryologiests
#
#       sentiment
# 1       -0.2500
# 2       -0.4215
# 3        0.0000
# 4        0.0000
# 5        0.0000
# ...         ...
# 1252    -0.2732
# 1253    -0.2732
# 1254     0.2960
# 1255     0.0000
# 1256    -0.2960
#
# [1256 rows x 2 columns]
# Average sentiment: -0.035
# Std dev:            0.231

# %%
col='Q2b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by the embryology profession, in general?
#                                                                                Q2b  \
# 1                                                                         Equality
# 2     Presence of narcissistic individuals destroying mental health of colleagues.
# 3                                                                    Certification
# 4                                                                         politics
# 5                                                                            Trust
# ...                                                                            ...
# 1252                                                      weekend and holiday work
# 1253                                                      Weekend and holiday work
# 1254                                 lack of respect for the work we do by doctors
# 1255                                                      Limit work opportunities
# 1256                                                    costs to be trained abroad
#
#       sentiment
# 1        0.0000
# 2       -0.5574
# 3        0.0000
# 4        0.0000
# 5        0.5106
# ...         ...
# 1252     0.4019
# 1253     0.4019
# 1254     0.2023
# 1255     0.3818
# 1256     0.0000
#
# [1256 rows x 2 columns]
# Average sentiment: -0.038
# Std dev:            0.239

# %%
col='Q3a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# Provide TWO suggestions to improve embryologists' working conditions
#                                                                                                                                                  Q3a  \
# 1                                                                                                                                     Improve number
# 2     Screening for sociopathic personality traits needs to be introduced.  A 45 minute interview is no way to select for entry into the profession.
# 3                                                                                   Add reading and projects into basic workload not in leisure time
# 4                                                                                                                                         better pay
# 5                                                                                                                           Good laboratory training
# ...                                                                                                                                              ...
# 1252                                                                                                                               increase salaries
# 1253                                                                                                                                 Higher salaries
# 1254                                                                                                                                       Pay them!
# 1255                                                                                                                                 Better salaries
# 1256                                                                                                         havng university programs in embryology
#
#       sentiment
# 1        0.4939
# 2       -0.2960
# 3        0.0000
# 4        0.3612
# 5        0.4404
# ...         ...
# 1252     0.3182
# 1253     0.0000
# 1254    -0.1759
# 1255     0.4404
# 1256     0.0000
#
# [1256 rows x 2 columns]
# Average sentiment: 0.126
# Std dev:           0.223

# %%
col='Q3b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# Provide TWO suggestions to improve embryologists' working conditions
#                                                                                                                                                  Q3b  \
# 1                                                                                                                                        Improve pay
# 2     Clinics must be staffed so that there is a good margin of available workers so that staff are not pressured to work at 110% and then burn out.
# 3                                                          Understand for how many hours a brain can be functional performing lab procedures per day
# 4                                                                                                                           better CPD opportunities
# 5                                                                                                                                    Troubleshooting
# ...                                                                                                                                              ...
# 1252                                                                                                                            close over christmas
# 1253                                                                                                                   Close over Christmas holidays
# 1254                                                                          Invite financial incentives to the embryologists as well. e.g. Shares!
# 1255                                                                                                                          Flexible working hours
# 1256                                                                                           having fellowships or grants to perform this programs
#
#       sentiment
# 1        0.3612
# 2        0.5523
# 3        0.0000
# 4        0.6705
# 5        0.1779
# ...         ...
# 1252     0.0000
# 1253     0.3818
# 1254     0.7574
# 1255     0.2263
# 1256     0.2263
#
# [1256 rows x 2 columns]
# Average sentiment: 0.148
# Std dev:           0.240

# %%
col='Q4'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What is your career goal?
#                                                                                                                                    Q4  \
# 1                                                                                                                            Continue
# 2                                    To survive until retirement without suffering mental illness or making a catestrophic lab error.
# 3     Get my ESHRE certification  Publish paper through research   Presentations and leading workshops   Acquire lab directing skills
# 4                                                                                                                             FRCPath
# 5                                                                                  Be confident in the work i do  Academically strong
# ...                                                                                                                               ...
# 1252                                                                                                          Dont make a big mistake
# 1253                                                                                               Make babies and make people happy.
# 1254                                  I reached the glass ceiling. All I can do is hope to study further and further and further.....
# 1255                                                                                                              Laboratory director
# 1256                                                                                                  being able to help our patients
#
#       sentiment
# 1        0.0000
# 2        0.2760
# 3        0.0000
# 4        0.0000
# 5        0.7579
# ...         ...
# 1252     0.2584
# 1253     0.5719
# 1254     0.5106
# 1255     0.0000
# 1256     0.4019
#
# [1256 rows x 2 columns]
# Average sentiment: 0.198
# Std dev:           0.306

# %% [markdown]
# ## Iterate over all columns

# %%
for col_name, col in df.items():
    print(col_name)
    # print(series)
    col.apply(get_sentiment)
# Out:
# Q1a
# Q1b
# Q2a
# Q2b
# Q3a
# Q3b
# Q4
# sentiment
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[117], line 4
#       2 print(col_name)
#       3 # print(series)
# ----> 4 col.apply(get_sentiment)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[81], line 3, in get_sentiment(text)
#       2 def get_sentiment(text):
# ----> 3     scores = analyzer.polarity_scores(text)
#       4     return scores['compound']
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/nltk/sentiment/vader.py:366, in SentimentIntensityAnalyzer.polarity_scores(self, text)
#     355 """
#     356 Return a float for sentiment strength based on the input text.
#     357 Positive values are positive valence, negative value are negative
#    (...)
#     363     matched as if it was a normal word in the sentence.
#     364 """
#     365 # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
# --> 366 sentitext = SentiText(
#     367     text, self.constants.PUNC_LIST, self.constants.REGEX_REMOVE_PUNCTUATION
#     368 )
#     369 sentiments = []
#     370 words_and_emoticons = sentitext.words_and_emoticons
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/nltk/sentiment/vader.py:270, in SentiText.__init__(self, text, punc_list, regex_remove_punctuation)
#     268 def __init__(self, text, punc_list, regex_remove_punctuation):
#     269     if not isinstance(text, str):
# --> 270         text = str(text.encode("utf-8"))
#     271     self.text = text
#     272     self.PUNC_LIST = punc_list
#
# AttributeError: 'float' object has no attribute 'encode'

# %%
col=list(df )
for i in col:
    #printing the 2nd element of the column
  print(df[i][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/indexes/range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 4
#       1 col=list(df )
#       2 for i in col:
#       3     #printing the 2nd element of the column
# ----> 4   print(df[i][0])
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/indexes/range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: 0

# %%
col=list(df )
for i in col:
    print(df[i][1])
    df[i].apply(get_sentiment)
# Out:
# Equality with clinical members
# Poor pay
# Shortage of trained staff
# Equality
# Improve number
# Improve pay
# Continue
# 0.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[113], line 4
#       2 for i in col:
#       3     print(df[i][1])
# ----> 4     df[i].apply(get_sentiment)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/pandas/core/algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[81], line 3, in get_sentiment(text)
#       2 def get_sentiment(text):
# ----> 3     scores = analyzer.polarity_scores(text)
#       4     return scores['compound']
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/nltk/sentiment/vader.py:366, in SentimentIntensityAnalyzer.polarity_scores(self, text)
#     355 """
#     356 Return a float for sentiment strength based on the input text.
#     357 Positive values are positive valence, negative value are negative
#    (...)
#     363     matched as if it was a normal word in the sentence.
#     364 """
#     365 # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
# --> 366 sentitext = SentiText(
#     367     text, self.constants.PUNC_LIST, self.constants.REGEX_REMOVE_PUNCTUATION
#     368 )
#     369 sentiments = []
#     370 words_and_emoticons = sentitext.words_and_emoticons
#
# File ~/anaconda3/envs/SurveyAnalysis/lib/python3.11/site-packages/nltk/sentiment/vader.py:270, in SentiText.__init__(self, text, punc_list, regex_remove_punctuation)
#     268 def __init__(self, text, punc_list, regex_remove_punctuation):
#     269     if not isinstance(text, str):
# --> 270         text = str(text.encode("utf-8"))
#     271     self.text = text
#     272     self.PUNC_LIST = punc_list
#
# AttributeError: 'float' object has no attribute 'encode'

# %% [markdown]
# ## Compare cohorts

# %% [markdown]
# ### 1. Female

# %%
# read csv ignoring potential N/As
df = pd.read_csv('Data/female.csv', na_filter = False)

# %%
df
# Out:
#     What are the TWO major challenges faced by embryologists in the workplace?  \
# 0                                                    1
# 1                       Equality with clinical members
# 2          Working hours and too many responsibilities
# 3                                       burnout/stress
# 4                                          Recognizion
# ..                                                 ...
# 853                                       Low Salaries
# 854                                       low salaries
# 855                                       Low salaries
# 856  Respect from other departments for the complex...
# 857                                      limited staff
#
#                                    Unnamed: 1  \
# 0                                           2
# 1                                    Poor pay
# 2                                      Salary
# 3                             poor management
# 4                                       Trust
# ..                                        ...
# 853                          Working weekends
# 854                  weekend and holiday work
# 855                  Weekend and holiday work
# 856  Financial compensation for overtime etc.
# 857                                   doctors
#
#     What are the TWO major challenges faced by the embryology profession, in general?   \
# 0                                                    1
# 1                            Shortage of trained staff
# 2                                   Access to training
# 3                      not enough highly trained staff
# 4                                     Handson training
# ..                                                 ...
# 853                          Not closing over December
# 854                                       low salaries
# 855                                         Low salary
# 856             Financial participation: Owning shares
# 857                                           Salaries
#
#                                         Unnamed: 3  \
# 0                                                2
# 1                                         Equality
# 2                                    Certification
# 3                                         politics
# 4                                            Trust
# ..                                             ...
# 853                                   Low Salaries
# 854                       weekend and holiday work
# 855                       Weekend and holiday work
# 856  lack of respect for the work we do by doctors
# 857                       Limit work opportunities
#
#     Provide TWO suggestions to improve embryologists' working conditions  \
# 0                                                    1
# 1                                       Improve number
# 2    Add reading and projects into basic workload n...
# 3                                           better pay
# 4                             Good laboratory training
# ..                                                 ...
# 853                                    Higher salaries
# 854                                  increase salaries
# 855                                    Higher salaries
# 856                                          Pay them!
# 857                                    Better salaries
#
#                                             Unnamed: 5  \
# 0                                                    2
# 1                                          Improve pay
# 2    Understand for how many hours a brain can be f...
# 3                             better CPD opportunities
# 4                                      Troubleshooting
# ..                                                 ...
# 853                              Closing over December
# 854                               close over christmas
# 855                      Close over Christmas holidays
# 856  Invite financial incentives to the embryologis...
# 857                             Flexible working hours
#
#                              What is your career goal?
# 0                                  Open-Ended Response
# 1                                             Continue
# 2    Get my ESHRE certification  Publish paper thro...
# 3                                              FRCPath
# 4    Be confident in the work i do  Academically st...
# ..                                                 ...
# 853  To complete my masters and become the best pra...
# 854                            Dont make a big mistake
# 855                 Make babies and make people happy.
# 856  I reached the glass ceiling. All I can do is h...
# 857                                Laboratory director
#
# [858 rows x 7 columns]

# %%
# create a dict for the short and log column names
long_col_names = {'Q1a': df.columns[0], 'Q1b': df.columns[0], 'Q2a': df.columns[2], 'Q2b': df.columns[2], \
                  'Q3a': df.columns[4], 'Q3b': df.columns[4], 'Q4': df.columns[6]}

# %%
long_col_names
# Out:
# {'Q1a': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q1b': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q2a': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q2b': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q3a': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q3b': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q4': 'What is your career goal?'}

# %%
# rename the columns
df = df.rename(columns={df.columns[0]: 'Q1a', df.columns[1]: 'Q1b', df.columns[2]: 'Q2a',df.columns[3]: \
                        'Q2b', df.columns[4]: 'Q3a', df.columns[5]: 'Q3b', df.columns[6]: 'Q4'})

# %%
# remove first row
df = df.iloc[1:]

# %%
df
# Out:
#                                                    Q1a  \
# 1                       Equality with clinical members
# 2          Working hours and too many responsibilities
# 3                                       burnout/stress
# 4                                          Recognizion
# 5                           General workplace politics
# ..                                                 ...
# 853                                       Low Salaries
# 854                                       low salaries
# 855                                       Low salaries
# 856  Respect from other departments for the complex...
# 857                                      limited staff
#
#                                           Q1b  \
# 1                                    Poor pay
# 2                                      Salary
# 3                             poor management
# 4                                       Trust
# 5                           Internal Pressure
# ..                                        ...
# 853                          Working weekends
# 854                  weekend and holiday work
# 855                  Weekend and holiday work
# 856  Financial compensation for overtime etc.
# 857                                   doctors
#
#                                         Q2a  \
# 1                 Shortage of trained staff
# 2                        Access to training
# 3           not enough highly trained staff
# 4                          Handson training
# 5                               Undervalued
# ..                                      ...
# 853               Not closing over December
# 854                            low salaries
# 855                              Low salary
# 856  Financial participation: Owning shares
# 857                                Salaries
#
#                                                Q2b  \
# 1                                         Equality
# 2                                    Certification
# 3                                         politics
# 4                                            Trust
# 5                                        Underpaid
# ..                                             ...
# 853                                   Low Salaries
# 854                       weekend and holiday work
# 855                       Weekend and holiday work
# 856  lack of respect for the work we do by doctors
# 857                       Limit work opportunities
#
#                                                    Q3a  \
# 1                                       Improve number
# 2    Add reading and projects into basic workload n...
# 3                                           better pay
# 4                             Good laboratory training
# 5                      Flexible hours to reduce stress
# ..                                                 ...
# 853                                    Higher salaries
# 854                                  increase salaries
# 855                                    Higher salaries
# 856                                          Pay them!
# 857                                    Better salaries
#
#                                                    Q3b  \
# 1                                          Improve pay
# 2    Understand for how many hours a brain can be f...
# 3                             better CPD opportunities
# 4                                      Troubleshooting
# 5                         Shorter rotations in the Lab
# ..                                                 ...
# 853                              Closing over December
# 854                               close over christmas
# 855                      Close over Christmas holidays
# 856  Invite financial incentives to the embryologis...
# 857                             Flexible working hours
#
#                                                     Q4
# 1                                             Continue
# 2    Get my ESHRE certification  Publish paper thro...
# 3                                              FRCPath
# 4    Be confident in the work i do  Academically st...
# 5    I would like to work as an embryologist intern...
# ..                                                 ...
# 853  To complete my masters and become the best pra...
# 854                            Dont make a big mistake
# 855                 Make babies and make people happy.
# 856  I reached the glass ceiling. All I can do is h...
# 857                                Laboratory director
#
# [857 rows x 7 columns]

# %%
col='Q1a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by embryologists in the workplace?
#                                                            Q1a  sentiment
# 1                               Equality with clinical members     0.0000
# 2                  Working hours and too many responsibilities     0.0000
# 3                                               burnout/stress     0.0000
# 4                                                  Recognizion     0.0000
# 5                                   General workplace politics     0.0000
# ..                                                         ...        ...
# 853                                               Low Salaries    -0.2732
# 854                                               low salaries    -0.2732
# 855                                               Low salaries    -0.2732
# 856  Respect from other departments for the complex work we do     0.4767
# 857                                              limited staff    -0.2263
#
# [857 rows x 2 columns]
# Average sentiment: -0.047
# Std dev:            0.240

# %%
col='Q1b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by embryologists in the workplace?
#                                           Q1b  sentiment
# 1                                    Poor pay    -0.5423
# 2                                      Salary     0.0000
# 3                             poor management    -0.4767
# 4                                       Trust     0.5106
# 5                           Internal Pressure    -0.2960
# ..                                        ...        ...
# 853                          Working weekends     0.0000
# 854                  weekend and holiday work     0.4019
# 855                  Weekend and holiday work     0.4019
# 856  Financial compensation for overtime etc.     0.0000
# 857                                   doctors     0.0000
#
# [857 rows x 2 columns]
# Average sentiment: -0.048
# Std dev:            0.240

# %%
col='Q2a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by the embryology profession, in general?
#                                         Q2a  sentiment
# 1                 Shortage of trained staff    -0.2500
# 2                        Access to training     0.0000
# 3           not enough highly trained staff     0.0000
# 4                          Handson training     0.0000
# 5                               Undervalued     0.0000
# ..                                      ...        ...
# 853               Not closing over December     0.0000
# 854                            low salaries    -0.2732
# 855                              Low salary    -0.2732
# 856  Financial participation: Owning shares     0.2960
# 857                                Salaries     0.0000
#
# [857 rows x 2 columns]
# Average sentiment: -0.031
# Std dev:            0.226

# %%
col='Q2b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by the embryology profession, in general?
#                                                Q2b  sentiment
# 1                                         Equality     0.0000
# 2                                    Certification     0.0000
# 3                                         politics     0.0000
# 4                                            Trust     0.5106
# 5                                        Underpaid     0.0000
# ..                                             ...        ...
# 853                                   Low Salaries    -0.2732
# 854                       weekend and holiday work     0.4019
# 855                       Weekend and holiday work     0.4019
# 856  lack of respect for the work we do by doctors     0.2023
# 857                       Limit work opportunities     0.3818
#
# [857 rows x 2 columns]
# Average sentiment: -0.042
# Std dev:            0.241

# %%
col='Q3a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# Provide TWO suggestions to improve embryologists' working conditions
#                                                                   Q3a  \
# 1                                                      Improve number
# 2    Add reading and projects into basic workload not in leisure time
# 3                                                          better pay
# 4                                            Good laboratory training
# 5                                     Flexible hours to reduce stress
# ..                                                                ...
# 853                                                   Higher salaries
# 854                                                 increase salaries
# 855                                                   Higher salaries
# 856                                                         Pay them!
# 857                                                   Better salaries
#
#      sentiment
# 1       0.4939
# 2       0.0000
# 3       0.3612
# 4       0.4404
# 5      -0.2263
# ..         ...
# 853     0.0000
# 854     0.3182
# 855     0.0000
# 856    -0.1759
# 857     0.4404
#
# [857 rows x 2 columns]
# Average sentiment: 0.125
# Std dev:           0.223

# %%
col='Q3b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# Provide TWO suggestions to improve embryologists' working conditions
#                                                                                            Q3b  \
# 1                                                                                  Improve pay
# 2    Understand for how many hours a brain can be functional performing lab procedures per day
# 3                                                                     better CPD opportunities
# 4                                                                              Troubleshooting
# 5                                                                 Shorter rotations in the Lab
# ..                                                                                         ...
# 853                                                                      Closing over December
# 854                                                                       close over christmas
# 855                                                              Close over Christmas holidays
# 856                     Invite financial incentives to the embryologists as well. e.g. Shares!
# 857                                                                     Flexible working hours
#
#      sentiment
# 1       0.3612
# 2       0.0000
# 3       0.6705
# 4       0.1779
# 5       0.0000
# ..         ...
# 853     0.0000
# 854     0.0000
# 855     0.3818
# 856     0.7574
# 857     0.2263
#
# [857 rows x 2 columns]
# Average sentiment: 0.150
# Std dev:           0.242

# %%
col='Q4'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What is your career goal?
#                                                                                                                                                                                                               Q4  \
# 1                                                                                                                                                                                                       Continue
# 2                                                                                Get my ESHRE certification  Publish paper through research   Presentations and leading workshops   Acquire lab directing skills
# 3                                                                                                                                                                                                        FRCPath
# 4                                                                                                                                                             Be confident in the work i do  Academically strong
# 5    I would like to work as an embryologist internationally, hopefully one day obtain my PhD. I would like to influence up and coming embryologists and have an active role in research within the field of ART
# ..                                                                                                                                                                                                           ...
# 853                                                                                                                           To complete my masters and become the best practical embryologist to my abilities.
# 854                                                                                                                                                                                      Dont make a big mistake
# 855                                                                                                                                                                           Make babies and make people happy.
# 856                                                                                                              I reached the glass ceiling. All I can do is hope to study further and further and further.....
# 857                                                                                                                                                                                          Laboratory director
#
#      sentiment
# 1       0.0000
# 2       0.0000
# 3       0.0000
# 4       0.7579
# 5       0.8555
# ..         ...
# 853     0.7351
# 854     0.2584
# 855     0.5719
# 856     0.5106
# 857     0.0000
#
# [857 rows x 2 columns]
# Average sentiment: 0.190
# Std dev:           0.306

# %% [markdown]
# ### 2. Male

# %%
# read csv ignoring potential N/As
df = pd.read_csv('Data/male.csv', na_filter = False)

# %%
df
# Out:
#     What are the TWO major challenges faced by embryologists in the workplace?  \
# 0                                                    1
# 1                  Bullying by colleagues and managers
# 2    Stress created by no embryos/ less embryos/ po...
# 3                                   lack of leadership
# 4                                        work overload
# ..                                                 ...
# 381  Access to knowledge about QC / QA and the tool...
# 382                       Motivation (stress, burnout)
# 383  not getting enough working materials, in ethiopia
# 384                    Too many cases per embryologist
# 385                                           Training
#
#                                             Unnamed: 1  \
# 0                                                    2
# 1    Poorly designed protocols, technical ignorance...
# 2                                           No respect
# 3                                              burnout
# 4                      No/less support from clinicians
# ..                                                 ...
# 381                             Learning embryo biopsy
# 382                              Getting the work done
# 383  to get Professional maintenance is difficult i...
# 384                                Not enough off-time
# 385  Being able to have technical and manual capaci...
#
#     What are the TWO major challenges faced by the embryology profession, in general?   \
# 0                                                    1
# 1    Stress of delivering high quality work without...
# 2    Gossips of others which disturbs other Embryol...
# 3                                            managment
# 4                                          Poor salary
# ..                                                 ...
# 381          Earn a salary according to the profession
# 382                                  Safety in the lab
# 383     maintaining the quality control in the IVF lab
# 384                       Continuous skill development
# 385  There are no university programs for embryolog...
#
#                                             Unnamed: 3  \
# 0                                                    2
# 1    Presence of narcissistic individuals destroyin...
# 2                                           No respect
# 3                                                   AI
# 4          Expected to work hard and give good results
# ..                                                 ...
# 381                           Professional recognition
# 382                                    Deliver quality
# 383              training of good embryology  staffs,
# 384                                   Not enough staff
# 385                         costs to be trained abroad
#
#     Provide TWO suggestions to improve embryologists' working conditions  \
# 0                                                    1
# 1    Screening for sociopathic personality traits n...
# 2    Reporting Manager should understand the situation
# 3                train managers to lead and not manage
# 4                     Constant support form clinicians
# ..                                                 ...
# 381                         Improve access to training
# 382                          even distribution of work
# 383             having good embryology training center
# 384             More staff to allow more personal time
# 385            havng university programs in embryology
#
#                                             Unnamed: 5  \
# 0                                                    2
# 1    Clinics must be staffed so that there is a goo...
# 2                               Stress free atmosphere
# 3                                          recognition
# 4    Increase salaries or pay better and relative t...
# ..                                                 ...
# 381                                      Improve wages
# 382                           provide sufficient staff
# 383  support technicians financially to get trainin...
# 384         More opportunities to better our knowledge
# 385  having fellowships or grants to perform this p...
#
#                              What is your career goal?
# 0                                  Open-Ended Response
# 1    To survive until retirement without suffering ...
# 2    To be Good Embryologist by providing  maximum ...
# 3                                    have a happy team
# 4    To achieve high position and personal developm...
# ..                                                 ...
# 381   Have the best reproductive results in my country
# 382                                                PhD
# 383                                 be ART researcher.
# 384  To be the best embryologist I can be to the pa...
# 385                    being able to help our patients
#
# [386 rows x 7 columns]

# %%
# create a dict for the short and log column names
long_col_names = {'Q1a': df.columns[0], 'Q1b': df.columns[0], 'Q2a': df.columns[2], 'Q2b': df.columns[2], \
                  'Q3a': df.columns[4], 'Q3b': df.columns[4], 'Q4': df.columns[6]}

# %%
long_col_names
# Out:
# {'Q1a': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q1b': 'What are the TWO major challenges faced by embryologists in the workplace?',
#  'Q2a': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q2b': 'What are the TWO major challenges faced by the embryology profession, in general? ',
#  'Q3a': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q3b': "Provide TWO suggestions to improve embryologists' working conditions",
#  'Q4': 'What is your career goal?'}

# %%
# rename the columns
df = df.rename(columns={df.columns[0]: 'Q1a', df.columns[1]: 'Q1b', df.columns[2]: 'Q2a',df.columns[3]: \
                        'Q2b', df.columns[4]: 'Q3a', df.columns[5]: 'Q3b', df.columns[6]: 'Q4'})

# %%
# remove first row
df = df.iloc[1:]

# %%
df
# Out:
#                                                    Q1a  \
# 1                  Bullying by colleagues and managers
# 2    Stress created by no embryos/ less embryos/ po...
# 3                                   lack of leadership
# 4                                        work overload
# 5                                   Time spent at work
# ..                                                 ...
# 381  Access to knowledge about QC / QA and the tool...
# 382                       Motivation (stress, burnout)
# 383  not getting enough working materials, in ethiopia
# 384                    Too many cases per embryologist
# 385                                           Training
#
#                                                    Q1b  \
# 1    Poorly designed protocols, technical ignorance...
# 2                                           No respect
# 3                                              burnout
# 4                      No/less support from clinicians
# 5                               Money for new quipment
# ..                                                 ...
# 381                             Learning embryo biopsy
# 382                              Getting the work done
# 383  to get Professional maintenance is difficult i...
# 384                                Not enough off-time
# 385  Being able to have technical and manual capaci...
#
#                                                    Q2a  \
# 1    Stress of delivering high quality work without...
# 2    Gossips of others which disturbs other Embryol...
# 3                                            managment
# 4                                          Poor salary
# 5                                           Low salary
# ..                                                 ...
# 381          Earn a salary according to the profession
# 382                                  Safety in the lab
# 383     maintaining the quality control in the IVF lab
# 384                       Continuous skill development
# 385  There are no university programs for embryolog...
#
#                                                    Q2b  \
# 1    Presence of narcissistic individuals destroyin...
# 2                                           No respect
# 3                                                   AI
# 4          Expected to work hard and give good results
# 5                                               Stress
# ..                                                 ...
# 381                           Professional recognition
# 382                                    Deliver quality
# 383              training of good embryology  staffs,
# 384                                   Not enough staff
# 385                         costs to be trained abroad
#
#                                                    Q3a  \
# 1    Screening for sociopathic personality traits n...
# 2    Reporting Manager should understand the situation
# 3                train managers to lead and not manage
# 4                     Constant support form clinicians
# 5                                           More staff
# ..                                                 ...
# 381                         Improve access to training
# 382                          even distribution of work
# 383             having good embryology training center
# 384             More staff to allow more personal time
# 385            havng university programs in embryology
#
#                                                    Q3b  \
# 1    Clinics must be staffed so that there is a goo...
# 2                               Stress free atmosphere
# 3                                          recognition
# 4    Increase salaries or pay better and relative t...
# 5                                        more off time
# ..                                                 ...
# 381                                      Improve wages
# 382                           provide sufficient staff
# 383  support technicians financially to get trainin...
# 384         More opportunities to better our knowledge
# 385  having fellowships or grants to perform this p...
#
#                                                     Q4
# 1    To survive until retirement without suffering ...
# 2    To be Good Embryologist by providing  maximum ...
# 3                                    have a happy team
# 4    To achieve high position and personal developm...
# 5              Best success rate to promote our clinic
# ..                                                 ...
# 381   Have the best reproductive results in my country
# 382                                                PhD
# 383                                 be ART researcher.
# 384  To be the best embryologist I can be to the pa...
# 385                    being able to help our patients
#
# [385 rows x 7 columns]

# %%
col='Q1a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by embryologists in the workplace?
#                                                                   Q1a  \
# 1                                 Bullying by colleagues and managers
# 2    Stress created by no embryos/ less embryos/ poor quality embryos
# 3                                                  lack of leadership
# 4                                                       work overload
# 5                                                  Time spent at work
# ..                                                                ...
# 381     Access to knowledge about QC / QA and the tools to apply them
# 382                                      Motivation (stress, burnout)
# 383                 not getting enough working materials, in ethiopia
# 384                                   Too many cases per embryologist
# 385                                                          Training
#
#      sentiment
# 1      -0.5994
# 2      -0.7024
# 3      -0.3182
# 4      -0.3612
# 5       0.0000
# ..         ...
# 381     0.0000
# 382     0.3400
# 383     0.0000
# 384     0.0000
# 385     0.0000
#
# [385 rows x 2 columns]
# Average sentiment: -0.037
# Std dev:            0.237

# %%
col='Q1b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by embryologists in the workplace?
#                                                                              Q1b  \
# 1    Poorly designed protocols, technical ignorance by colleagues and managers.
# 2                                                                     No respect
# 3                                                                        burnout
# 4                                                No/less support from clinicians
# 5                                                         Money for new quipment
# ..                                                                           ...
# 381                                                       Learning embryo biopsy
# 382                                                        Getting the work done
# 383                      to get Professional maintenance is difficult in my area
# 384                                                          Not enough off-time
# 385                           Being able to have technical and manual capacities
#
#      sentiment
# 1      -0.3612
# 2       0.2263
# 3       0.0000
# 4       0.4019
# 5       0.0000
# ..         ...
# 381     0.0000
# 382     0.0000
# 383    -0.3612
# 384     0.0000
# 385     0.0000
#
# [385 rows x 2 columns]
# Average sentiment: -0.054
# Std dev:            0.251

# %%
col='Q2a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by the embryology profession, in general?
#                                                                   Q2a  \
# 1    Stress of delivering high quality work without sufficient staff.
# 2            Gossips of others which disturbs other Embryologist work
# 3                                                           managment
# 4                                                         Poor salary
# 5                                                          Low salary
# ..                                                                ...
# 381                         Earn a salary according to the profession
# 382                                                 Safety in the lab
# 383                    maintaining the quality control in the IVF lab
# 384                                      Continuous skill development
# 385               There are no university programs for embryologiests
#
#      sentiment
# 1      -0.4215
# 2      -0.6369
# 3       0.0000
# 4      -0.4767
# 5      -0.2732
# ..         ...
# 381     0.0000
# 382     0.4215
# 383     0.0000
# 384     0.0000
# 385    -0.2960
#
# [385 rows x 2 columns]
# Average sentiment: -0.040
# Std dev:            0.241

# %%
col='Q2b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:16.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What are the TWO major challenges faced by the embryology profession, in general?
#                                                                               Q2b  \
# 1    Presence of narcissistic individuals destroying mental health of colleagues.
# 2                                                                      No respect
# 3                                                                              AI
# 4                                     Expected to work hard and give good results
# 5                                                                          Stress
# ..                                                                            ...
# 381                                                      Professional recognition
# 382                                                               Deliver quality
# 383                                         training of good embryology  staffs,
# 384                                                              Not enough staff
# 385                                                    costs to be trained abroad
#
#      sentiment
# 1      -0.5574
# 2       0.2263
# 3       0.0000
# 4       0.3612
# 5      -0.4215
# ..         ...
# 381     0.0000
# 382     0.0000
# 383     0.4404
# 384     0.0000
# 385     0.0000
#
# [385 rows x 2 columns]
# Average sentiment: -0.024
# Std dev:            0.231

# %%
col='Q3a'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# Provide TWO suggestions to improve embryologists' working conditions
#                                                                                                                                                 Q3a  \
# 1    Screening for sociopathic personality traits needs to be introduced.  A 45 minute interview is no way to select for entry into the profession.
# 2                                                                                                 Reporting Manager should understand the situation
# 3                                                                                                             train managers to lead and not manage
# 4                                                                                                                  Constant support form clinicians
# 5                                                                                                                                        More staff
# ..                                                                                                                                              ...
# 381                                                                                                                      Improve access to training
# 382                                                                                                                       even distribution of work
# 383                                                                                                          having good embryology training center
# 384                                                                                                          More staff to allow more personal time
# 385                                                                                                         havng university programs in embryology
#
#      sentiment
# 1      -0.2960
# 2       0.0000
# 3       0.0000
# 4       0.4019
# 5       0.0000
# ..         ...
# 381     0.4404
# 382     0.0000
# 383     0.4404
# 384     0.2878
# 385     0.0000
#
# [385 rows x 2 columns]
# Average sentiment: 0.128
# Std dev:           0.222

# %%
col='Q3b'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# Provide TWO suggestions to improve embryologists' working conditions
#                                                                                                                                                 Q3b  \
# 1    Clinics must be staffed so that there is a good margin of available workers so that staff are not pressured to work at 110% and then burn out.
# 2                                                                                                                            Stress free atmosphere
# 3                                                                                                                                       recognition
# 4                                                                                      Increase salaries or pay better and relative to the workload
# 5                                                                                                                                     more off time
# ..                                                                                                                                              ...
# 381                                                                                                                                   Improve wages
# 382                                                                                                                        provide sufficient staff
# 383                                                                                          support technicians financially to get training abroad
# 384                                                                                                      More opportunities to better our knowledge
# 385                                                                                           having fellowships or grants to perform this programs
#
#      sentiment
# 1       0.5523
# 2       0.1280
# 3       0.0000
# 4       0.5859
# 5       0.0000
# ..         ...
# 381     0.4404
# 382     0.0000
# 383     0.4019
# 384     0.7233
# 385     0.2263
#
# [385 rows x 2 columns]
# Average sentiment: 0.145
# Std dev:           0.236

# %%
col='Q4'
print(long_col_names[col])
df['sentiment'] = df[col].apply(get_compound_sentiment)
with pd.option_context('display.max_colwidth', None):
    display(df[[col, 'sentiment']])
print("Average sentiment: {0:2.3f}".format(df.loc[:, 'sentiment'].mean()))
print("Std dev: {0:15.3f}".format(df.loc[:, 'sentiment'].std()))
# Out:
# What is your career goal?
#                                                                                                    Q4  \
# 1    To survive until retirement without suffering mental illness or making a catestrophic lab error.
# 2          To be Good Embryologist by providing  maximum effort and good professor by teaching others
# 3                                                                                   have a happy team
# 4              To achieve high position and personal development (lab director or chief technologist)
# 5                                                             Best success rate to promote our clinic
# ..                                                                                                ...
# 381                                                  Have the best reproductive results in my country
# 382                                                                                               PhD
# 383                                                                                be ART researcher.
# 384                                             To be the best embryologist I can be to the patients.
# 385                                                                   being able to help our patients
#
#      sentiment
# 1       0.2760
# 2       0.7003
# 3       0.5719
# 4       0.0000
# 5       0.8885
# ..         ...
# 381     0.6369
# 382     0.0000
# 383     0.0000
# 384     0.6369
# 385     0.4019
#
# [385 rows x 2 columns]
# Average sentiment: 0.213
# Std dev:           0.307

# %% [markdown]
# ## Comparison

# %% [markdown]
# | Q                 | Female   | Male| Average |
# | :---------------- | :------: | ----: | ----: |
# | Q1a               |   -0.047  | -0.037 | -0.045 |
# | Q1b               |   -0.048  | -0.054 | -0.051 |
# | Q2a               |   -0.031  | -0.040 | -0.035 |
# | Q2b               |   -0.042  | -0.024 | -0.038 |
# | Q3a               |   0.125   | 0.128 | 0.126 |
# | Q3b               |   0.150   | 0.145 | 0.148 |
# | Q4               |   0.190   | 0.213 | 0.198 |
